# %%
import pandas as pd

# %%
df_23 = pd.read_csv('laliga_data_2023.csv')
df_24 = pd.read_csv('laliga_data_2024.csv')
df_25 = pd.read_csv('laliga_data_2025.csv')

# %%
df_1 = pd.concat([df_23, df_24, df_25])

# %%
df_1.to_csv('LaLiga_Final.csv')

# %%
df_23 = pd.read_csv('premierleague_data_2023.csv')
df_24 = pd.read_csv('premierleague_data_2024.csv')
df_25 = pd.read_csv('premierleague_data_2025.csv')

df_2 = pd.concat([df_23, df_24, df_25])

# %%
df_2.to_csv('PremierLeague_Final.csv')

# %%
df_23 = pd.read_csv('bundesliga_data_2023.csv')
df_24 = pd.read_csv('bundesliga_data_2024.csv')
df_25 = pd.read_csv('bundesliga_data_2025.csv')

df_3 = pd.concat([df_23, df_24, df_25])

# %%
df_3.to_csv('Bundesliga_Final.csv')

# %%
df_23 = pd.read_csv('ligue_1_data_2023.csv')
df_24 = pd.read_csv('ligue_1_data_2024.csv')
df_25 = pd.read_csv('ligue_1_data_2025.csv')

df_4 = pd.concat([df_23, df_24, df_25])

# %%
df_4.to_csv('Ligue_1_Final.csv')

# %%
df_23 = pd.read_csv('serie_a_data_2023.csv')
df_24 = pd.read_csv('serie_a_data_2024.csv')
df_25 = pd.read_csv('serie_a_data_2025.csv')

df_5 = pd.concat([df_23, df_24, df_25])

# %%
df_5.to_csv('Serie_A_Final.csv')

# %%
df_final = pd.concat([df_1, df_2, df_3, df_4, df_5])

# %%
df_final.to_csv('All_Data.csv')
